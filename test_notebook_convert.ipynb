# %%
import pandas as pd
import numpy as np
#import matplotlib as matplot

# %%
covid = pd.read_csv("owid-covid-data.csv")

# %%
covid.groupby("date").sum().total_cases.plot();
# Out:
# <AxesSubplot:xlabel='date'>
